# %%
# 查看已安装R包
installed.packages()
# Out:
#            Package    LibPath                    Version     Priority
# base       base       D:/R-3.4.4/R-3.4.4/library 3.4.4       base
# boot       boot       D:/R-3.4.4/R-3.4.4/library 1.3-20      recommended
# class      class      D:/R-3.4.4/R-3.4.4/library 7.3-14      recommended
# cluster    cluster    D:/R-3.4.4/R-3.4.4/library 2.0.6       recommended
# codetools  codetools  D:/R-3.4.4/R-3.4.4/library 0.2-15      recommended
# compiler   compiler   D:/R-3.4.4/R-3.4.4/library 3.4.4       base
# crayon     crayon     D:/R-3.4.4/R-3.4.4/library 1.3.4       NA
# curl       curl       D:/R-3.4.4/R-3.4.4/library 3.1         NA
# datasets   datasets   D:/R-3.4.4/R-3.4.4/library 3.4.4       base
# devtools   devtools   D:/R-3.4.4/R-3.4.4/library 1.13.5      NA
# digest     digest     D:/R-3.4.4/R-3.4.4/library 0.6.15      NA
# evaluate   evaluate   D:/R-3.4.4/R-3.4.4/library 0.10.1      NA
# foreign    foreign    D:/R-3.4.4/R-3.4.4/library 0.8-69      recommended
# ...

# %%
# 查看当前工作目录
getwd()
# Out:
# [1] "C:/Users/Administrator/Desktop/R/R practice"

# %%
# 更改 包 下载路径
.libPaths()
# Out:
# [1] "D:/R-3.4.4/R-3.4.4/library"

# %%
# 通过如下命令设定镜像
options(repos = 'http://mirrors.ustc.edu.cn/CRAN/')

# %%
(.packages())
# Out:
# [1] "stats"     "graphics"  "grDevices" "utils"     "datasets"  "methods"
# [7] "base"

# %%
# R多层回归分析包
install.packages('AutoModel')
# Out:
# package 'AutoModel' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpQb2tTG\downloaded_packages

# %%
#R中介效应分析包
install.packages('mediation')
# Out:
# also installing the dependencies 'colorspace', 'dichromat', 'munsell', 'labeling', 'highr', 'markdown', 'yaml', 'backports', 'scales', 'lazyeval', 'RColorBrewer', 'knitr', 'checkmate', 'htmlwidgets', 'viridisLite', 'Formula', 'ggplot2', 'latticeExtra', 'acepack', 'gtable', 'gridExtra', 'data.table', 'htmlTable', 'viridis', 'htmltools', 'base64enc', 'mvtnorm', 'sandwich', 'lpSolve', 'Hmisc'
# package 'colorspace' successfully unpacked and MD5 sums checked
# package 'dichromat' successfully unpacked and MD5 sums checked
# package 'munsell' successfully unpacked and MD5 sums checked
# package 'labeling' successfully unpacked and MD5 sums checked
# package 'highr' successfully unpacked and MD5 sums checked
# package 'markdown' successfully unpacked and MD5 sums checked
# package 'yaml' successfully unpacked and MD5 sums checked
# package 'backports' successfully unpacked and MD5 sums checked
# package 'scales' successfully unpacked and MD5 sums checked
# ...

# %%
#R调节回归分析包
install.packages('pequod')
# Out:
# package 'pequod' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R响应面分析
install.packages('RSA')
# Out:
# also installing the dependencies 'pbivnorm', 'quadprog', 'numDeriv', 'lavaan', 'tkrplot', 'aplpack'
# package 'pbivnorm' successfully unpacked and MD5 sums checked
# package 'quadprog' successfully unpacked and MD5 sums checked
# package 'numDeriv' successfully unpacked and MD5 sums checked
# package 'lavaan' successfully unpacked and MD5 sums checked
# package 'tkrplot' successfully unpacked and MD5 sums checked
# package 'aplpack' successfully unpacked and MD5 sums checked
# package 'RSA' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R响应面分析
install.packages('rsm')
# Out:
# also installing the dependency 'estimability'
# package 'estimability' successfully unpacked and MD5 sums checked
# package 'rsm' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R结构方程包
install.packages(c('rsm','lavaan','OpenMx','OpenMx','semTools'))
# Out:
# also installing the dependencies 'StanHeaders', 'rpf'
# package 'StanHeaders' successfully unpacked and MD5 sums checked
# package 'rpf' successfully unpacked and MD5 sums checked
# package 'rsm' successfully unpacked and MD5 sums checked
# package 'lavaan' successfully unpacked and MD5 sums checked
# package 'OpenMx' successfully unpacked and MD5 sums checked
# package 'semTools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R Multilevel分析包
install.packages(c('multilevel','lme4','nlme'))
# Out:
# package 'multilevel' successfully unpacked and MD5 sums checked
# package 'lme4' successfully unpacked and MD5 sums checked
# package 'nlme' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R元分析包
install.packages('metafor')
# Out:
# package 'metafor' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R图形与表格辅助工具
install.packages('sjPlot')
# Out:
# package 'sjPlot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R菜单式基本统计包
install.packages('Rcmdr')
# Out:
# also installing the dependencies 'rematch', 'cellranger', 'e1071', 'readstata13', 'readxl', 'nortest', 'RcmdrMisc', 'tcltk2', 'relimp'
# package 'rematch' successfully unpacked and MD5 sums checked
# package 'cellranger' successfully unpacked and MD5 sums checked
# package 'e1071' successfully unpacked and MD5 sums checked
# package 'readstata13' successfully unpacked and MD5 sums checked
# package 'readxl' successfully unpacked and MD5 sums checked
# package 'nortest' successfully unpacked and MD5 sums checked
# package 'RcmdrMisc' successfully unpacked and MD5 sums checked
# package 'tcltk2' successfully unpacked and MD5 sums checked
# package 'relimp' successfully unpacked and MD5 sums checked
# package 'Rcmdr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages

# %%
#R自动生成APA格式表格的的包1
install.packages('apa')
# Out:
# also installing the dependencies 'rprojroot', 'rmarkdown'
# package 'rprojroot' successfully unpacked and MD5 sums checked
# package 'rmarkdown' successfully unpacked and MD5 sums checked
# package 'apa' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpKG9s1h\downloaded_packages
