# %%
# 查看当前工作目录
getwd()
# Out:
# [1] "C:/Users/Administrator/Desktop/R/R practice"

# %%
# 设置工作目录
curwd=setwd("e:\\R practice")

# %%
getwd()
# Out:
# [1] "e:/R practice"

# %%
help(read.table)

# %%
# 用read.csv()函数读取
mydata <- read.csv("http://stats.idre.ucla.edu/wp-content/uploads/2016/02/test-1.csv", header=T) # 用read.csv()读取csv数据
print(mydata)                                                                                    # 显示数据
# Out:
#    make   model mpg weight price
# 1   amc concord  22   2930  4099
# 2   amc   oacer  17   3350  4749
# 3   amc  spirit  22   2640  3799
# 4 buick century  20   3250  4816
# 5 buick electra  15   4080  7827

# %%
options(repos = 'http://mirrors.ustc.edu.cn/CRAN/') # 通过如下命令设定镜像

# %%
install.packages('foreign')
# Out:
# package 'foreign' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpiMZEjd\downloaded_packages

# %%
# 读取SPSS、SAS、Stata等的数据文件，可以用foreign包中的函数。读取SPSS数据文件对应的函数是：read.spss()
library(foreign)

# %%
mydata <- read.spss("E:\\武汉大学硕士研究生作业及资料\\行为研究方法\\W 4\\Example_Creating dummy variables.sav",use.value.labels=FALSE)

# %%
print(mydata)
# Out:
# $age
#  [1] 23 26 24 30 29 27 32 34 28 22 22 25 21 19 18 17
#
# $area
#  [1] 1 2 2 1 1 2 1 2 1 2 1 2 2 1 1 2
# attr(,"value.labels")
# 北方 南方
#    2    1
#
# $edu
#  [1] 3 4 3 5 5 4 5 5 4 2 3 3 2 2 1 1
# attr(,"value.labels")
#       博士       硕士       本科       大专 高中及以下
#          5          4          3          2          1
#
# $salary
#  [1] 3000 4000 3202 5000 4800 4321 6211 5333 4121 1908 3543 2999 2098 2612  998
# [16] 1209
#
# attr(,"label.table")
# attr(,"label.table")$age
# NULL
#
# attr(,"label.table")$area
# 北方 南方
#    2    1
#
# attr(,"label.table")$edu
#       博士       硕士       本科       大专 高中及以下
#          5          4          3          2          1
#
# attr(,"label.table")$salary
# NULL
#
# attr(,"codepage")
# [1] 936

# %%
install.packages("xlsx")
# Out:
# also installing the dependencies 'rJava', 'xlsxjars'
# package 'rJava' successfully unpacked and MD5 sums checked
# package 'xlsxjars' successfully unpacked and MD5 sums checked
# package 'xlsx' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpiMZEjd\downloaded_packages

# %%
library(xlsx)                                                        # 启用xlsx包   
mydata <- read.xlsx("E:\\下载\\武汉大学17-18第一学期课表.xlsx",1)    # 读取数据
# Out:
# Loading required package: rJava
# Loading required package: xlsxjars
# Error in make.names(vnames, unique = TRUE): invalid multibyte string 1
# Traceback:
#
# 1. read.xlsx("E:\\下载\\武汉大学17-18第一学期课表.xlsx", 1)
# 2. data.frame(res, ...)
# 3. make.names(vnames, unique = TRUE)

# %%
# 更改 包 下载路径
.libPaths()
# Out:
# [1] "D:/R-3.4.4/R-3.4.4/library"

# %%
# 查看已安装R包
installed.packages()
# Out:
#               Package       LibPath                    Version  Priority
# abind         abind         D:/R-3.4.4/R-3.4.4/library 1.4-5    NA
# acepack       acepack       D:/R-3.4.4/R-3.4.4/library 1.4.1    NA
# aod           aod           D:/R-3.4.4/R-3.4.4/library 1.3      NA
# apa           apa           D:/R-3.4.4/R-3.4.4/library 0.2.0    NA
# aplpack       aplpack       D:/R-3.4.4/R-3.4.4/library 1.3.0    NA
# arm           arm           D:/R-3.4.4/R-3.4.4/library 1.9-3    NA
# assertthat    assertthat    D:/R-3.4.4/R-3.4.4/library 0.2.0    NA
# AutoModel     AutoModel     D:/R-3.4.4/R-3.4.4/library 0.4.9    NA
# backports     backports     D:/R-3.4.4/R-3.4.4/library 1.1.2    NA
# base          base          D:/R-3.4.4/R-3.4.4/library 3.4.4    base
# base64enc     base64enc     D:/R-3.4.4/R-3.4.4/library 0.1-3    NA
# bayesplot     bayesplot     D:/R-3.4.4/R-3.4.4/library 1.4.0    NA
# BaylorEdPsych BaylorEdPsych D:/R-3.4.4/R-3.4.4/library 0.5      NA
# ...

# %%
(.packages())
# Out:
# [1] "stats"     "graphics"  "grDevices" "utils"     "datasets"  "methods"
# [7] "base"
